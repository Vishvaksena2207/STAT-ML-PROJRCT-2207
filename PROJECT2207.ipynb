# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
calories=pd.read_csv('/content/calories.csv')

# %%
print(calories)
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
exercise_data = pd.read_csv('/content/exercise.csv')
print(exercise_data )
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
calories_data = pd.concat([exercise_data, calories['Calories']], axis=1)
print(calories_data)
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
x1=calories_data['Gender']
y=calories_data['Calories']
plt.bar(x1,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x2=calories_data['Age']
y=calories_data['Calories']
plt.bar(x2,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x3=calories_data['Height']
y=calories_data['Calories']
plt.bar(x3,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x4=calories_data['Weight']
y=calories_data['Calories']
plt.bar(x4,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x5=calories_data['Duration']
y=calories_data['Calories']
plt.bar(x5,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x6=calories_data['Heart_Rate']
y=calories_data['Calories']
plt.bar(x6,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
x7=calories_data['Body_Temp']
y=calories_data['Calories']
plt.bar(x7,y)
# Out:
# <BarContainer object of 15000 artists>

# %%
calories_data.replace({"Gender":{'male':0,'female':1}}, inplace=True)
print(calories_data)
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927       1   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082       1   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577       1   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188       1   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037       0   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526       0   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
X = calories_data.drop(columns=['User_ID','Calories'], axis=1)
Y = calories_data['Calories']

# %%
print(X)
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0           0   68   190.0    94.0      29.0       105.0       40.8
# 1           1   20   166.0    60.0      14.0        94.0       40.3
# 2           0   69   179.0    79.0       5.0        88.0       38.7
# 3           1   34   179.0    71.0      13.0       100.0       40.5
# 4           1   27   154.0    58.0      10.0        81.0       39.8
# ...       ...  ...     ...     ...       ...         ...        ...
# 14995       1   20   193.0    86.0      11.0        92.0       40.4
# 14996       1   27   165.0    65.0       6.0        85.0       39.2
# 14997       1   43   159.0    58.0      16.0        90.0       40.1
# 14998       0   78   193.0    97.0       2.0        84.0       38.3
# 14999       0   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 7 columns]

# %%
print(Y)
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
b=calories_data.fillna(0)
C=calories_data['Heart_Rate']
D=calories_data['Calories']
print(C)
print(D)
# Out:
# 0        105.0
# 1         94.0
# 2         88.0
# 3        100.0
# 4         81.0
#          ...
# 14995     92.0
# 14996     85.0
# 14997     90.0
# 14998     84.0
# 14999     92.0
# Name: Heart_Rate, Length: 15000, dtype: float64
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (15000, 7) (12000, 7) (3000, 7)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)
model=SVC(kernel='linear')
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.12566666666666668

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00         2
#          2.0       0.90      0.82      0.86        11
#          3.0       0.59      0.56      0.57        18
#          4.0       0.65      0.65      0.65        23
#          5.0       0.45      0.26      0.33        19
#          6.0       0.41      0.56      0.47        16
#          7.0       0.55      0.67      0.60        24
#          8.0       0.35      0.55      0.43        22
#          9.0       0.43      0.34      0.38        29
#         10.0       0.10      0.09      0.09        23
#         11.0       0.39      0.31      0.35        29
#         12.0       0.11      0.08      0.09        25
#         13.0       0.28      0.28      0.28        25
#         14.0       0.09      0.05      0.06        22
#         15.0       0.21      0.35      0.26        17
#         16.0       0.36      0.21      0.27        19
# ...

# %%
from sklearn import svm
svm_model = svm.SVC(kernel='linear')
svm_model.fit(X_train, Y_train)
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(Y_test,Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.12566666666666668

# %%
from sklearn.linear_model import Perceptron
perceptron_model = Perceptron()
perceptron_model.fit(X_train, Y_train)
y_pred = perceptron_model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.12566666666666668

# %%
test_data_prediction = model.predict(X_test)
print(test_data_prediction)
# Out:
# [174.3915    94.24485  111.64104  ... 199.23735    6.270635  53.993473]
